# %%
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import statsmodels.api
import pandas as pd 

from sklearn.feature_selection import VarianceThreshold

# %%
customers=pd.read_csv('olist_customers_dataset.csv')
print(f"customers table shape: {customers.shape}")
geolocation=pd.read_csv('olist_geolocation_dataset.csv')
print(f"geolocation table shape: {geolocation.shape}")
order_items=pd.read_csv('olist_order_items_dataset.csv')
print(f"order_items table shape: {order_items.shape}")
order_payments=pd.read_csv('olist_order_payments_dataset.csv')
print(f"order_payments table shape: {order_payments.shape}")
order_reviews=pd.read_csv('olist_order_reviews_dataset.csv')
print(f"order_reviews table shape: {order_reviews.shape}")
orders=pd.read_csv('olist_orders_dataset.csv')
print(f"orders table shape:{orders.shape}")
order_sellers=pd.read_csv('olist_sellers_dataset.csv')
print(f"order_sellers table shape:{order_sellers.shape}")
order_products=pd.read_csv('olist_products_dataset.csv')
print(f"order_products table shape: {order_products.shape}")
product_category=pd.read_csv('product_category_name_translation.csv')
print(f"product_category table shape: {product_category.shape}")
# Out:
# customers table shape: (99441, 5)
# geolocation table shape: (1000163, 5)
# order_items table shape: (112650, 7)
# order_payments table shape: (103886, 5)
# order_reviews table shape: (100000, 7)
# orders table shape:(99441, 8)
# order_sellers table shape:(3095, 4)
# order_products table shape: (32951, 9)
# product_category table shape: (71, 2)

# %%
list(customers.columns)
# Out:
# ['customer_id',
#  'customer_unique_id',
#  'customer_zip_code_prefix',
#  'customer_city',
#  'customer_state']

# %%
#customers_df=customers.copy()
#customers_df=customers_df.drop(columns=['customer_zip_code_prefix'])

# %%
list(geolocation.columns)
# Out:
# ['geolocation_zip_code_prefix',
#  'geolocation_lat',
#  'geolocation_lng',
#  'geolocation_city',
#  'geolocation_state']

# %%
list(order_items.columns)
# Out:
# ['order_id',
#  'order_item_id',
#  'product_id',
#  'seller_id',
#  'shipping_limit_date',
#  'price',
#  'freight_value']

# %%
#items_df=order_items.copy()
#items_df=items_df.drop(columns=[ 'shipping_limit_date'])

# %%
list(order_payments.columns)
# Out:
# ['order_id',
#  'payment_sequential',
#  'payment_type',
#  'payment_installments',
#  'payment_value']

# %%
#order_payments_df=order_payments.copy()
#order_payments_df=order_payments_df.drop(columns=[ 'payment_sequential'])

# %%
list(order_reviews.columns)
# Out:
# ['review_id',
#  'order_id',
#  'review_score',
#  'review_comment_title',
#  'review_comment_message',
#  'review_creation_date',
#  'review_answer_timestamp']

# %%
list(orders.columns)
# Out:
# ['order_id',
#  'customer_id',
#  'order_status',
#  'order_purchase_timestamp',
#  'order_approved_at',
#  'order_delivered_carrier_date',
#  'order_delivered_customer_date',
#  'order_estimated_delivery_date']

# %%
#orders_df=orders.copy()
#orders_df=orders_df.drop(columns=['order_approved_at'
#                                  , 'order_delivered_carrier_date'
#                                  , 'order_delivered_customer_date'
#                                  , 'order_estimated_delivery_date'])

# %%
list(order_sellers.columns)
# Out:
# ['seller_id', 'seller_zip_code_prefix', 'seller_city', 'seller_state']

# %%
list(order_products.columns)
# Out:
# ['product_id',
#  'product_category_name',
#  'product_name_lenght',
#  'product_description_lenght',
#  'product_photos_qty',
#  'product_weight_g',
#  'product_length_cm',
#  'product_height_cm',
#  'product_width_cm']

# %%
list(product_category.columns)
# Out:
# ['product_category_name', 'product_category_name_english']

# %%
#product_category_df=product_category.copy()
#product_category_df=product_category_df.drop(columns=[ 'product_category_name'])

# %%
number_records = str(len(customers))
number_customer_ids = str(customers["customer_id"].nunique())
num_unique_customers = str(customers['customer_unique_id'].nunique())
print("Total number of records: "+ number_records)
print("Number of unique customer_ids: "+ number_customer_ids)
print("Unique customer_ids: "+ num_unique_customers)
# Out:
# Total number of records: 99441
# Number of unique customer_ids: 99441
# Unique customer_ids: 96096

# %%
list(customers.columns)
# Out:
# ['customer_id',
#  'customer_unique_id',
#  'customer_zip_code_prefix',
#  'customer_city',
#  'customer_state']

# %%
product_info_english=order_products.merge(product_category,how="left",on="product_category_name")
product_info_english
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
product_info=product_info_english.merge(order_items,how="left",on="product_id")

# %%
product_info
# Out:
#                               product_id   product_category_name  \
# 0       1e9e8ef04dbcff4541ed26657ea517e5              perfumaria
# 1       3aa071139cb16b67ca9e5dea641aaa2f                   artes
# 2       96bd76ec8810374ed1b65e291975717f           esporte_lazer
# 3       cef67bcfe19066a932b7673e239eb23d                   bebes
# 4       9dc1a7de274444849c219cff195d0b71   utilidades_domesticas
# ...                                  ...                     ...
# 112645  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112646  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112647  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112648  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112649  106392145fca363410d287a815be6de4         cama_mesa_banho
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                      40.0                       287.0                 1.0
# ...

# %%
#product_info.drop(['product_category_name'], axis=1)

# %%
customers_merge_orders=orders.merge(customers,how="left",on="customer_id")
customers_merge_orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
customers_merge_order_and_reviews=customers_merge_orders.merge(order_reviews,how="left",on="order_id")
customers_merge_order_and_reviews.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
All_data = customers_merge_order_and_reviews.merge(order_payments,how="left",on="order_id")
All_data.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
list(All_data.columns)
# Out:
# ['order_id',
#  'customer_id',
#  'order_status',
#  'order_purchase_timestamp',
#  'order_approved_at',
#  'order_delivered_carrier_date',
#  'order_delivered_customer_date',
#  'order_estimated_delivery_date',
#  'customer_unique_id',
#  'customer_zip_code_prefix',
#  'customer_city',
#  'customer_state',
#  'review_id',
#  'review_score',
#  'review_comment_title',
#  'review_comment_message',
#  'review_creation_date',
#  'review_answer_timestamp',
#  'payment_sequential',
#  'payment_type',
#  'payment_installments',
#  'payment_value']

# %%
All_data.shape
# Out:
# (104486, 22)

# %%
All_data=All_data.drop_duplicates()
All_data.shape
# Out:
# (104486, 22)

# %%
All_data.to_csv("cleanedData.csv",index=False)
